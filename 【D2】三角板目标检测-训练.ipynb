# %% [markdown]
# # 三角板目标检测-训练
#
# 同济子豪兄 2023-4-3

# %% [markdown]
# ## 进入mmdetection主目录

# %%
import os
os.chdir('mmdetection')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-54e8636db2f1> in <module>
#       1 import os
# ----> 2 os.chdir('mmdetection')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mmdetection'

# %%
# !pwd
# Out:
# /media/zhou/B6E23E81E23E4641/OpenMMLab2Learn-main/mmdetection

# %% [markdown]
# ## 目标检测算法：Faster R CNN

# %%
# 建议在命令行中运行
# !python tools/train.py data/faster_r_cnn_triangle.py
# Out:
# 06/03 20:39:02 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.9 (default, Aug 31 2020, 12:42:55) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 1045462907
#     GPU 0: Graphics Device
#     CUDA_HOME: /usr/local/cuda-11.1
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.8.0+cu111
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v1.7.0 (Git Hash 7aed236906b1f7a05c0917e5257a1af05e9ff683)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.0.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.8.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.9.0+cu111
#     OpenCV: 4.5.1
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/03 20:39:02 - mmengine - INFO - Config:
# dataset_type = 'CocoDataset'
# data_root = 'data/Triangle_215_Keypoint_coco/'
# metainfo = dict(classes=('sjb_rect', ))
# NUM_CLASSES = 1
# load_from = None
# MAX_EPOCHS = 50
# TRAIN_BATCH_SIZE = 2
# VAL_BATCH_SIZE = 2
# VAL_INTERVAL = 5
# train_cfg = dict(type='EpochBasedTrainLoop', max_epochs=50, val_interval=5)
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=dict(type='AspectRatioBatchSampler'),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_215_Keypoint_coco/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='train_coco.json',
#         data_prefix=dict(img='images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='RandomFlip', prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None))
# val_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(classes=('sjb_rect', )),
#         data_root='data/Triangle_215_Keypoint_coco/',
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# test_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         metainfo=dict(classes=('sjb_rect', )),
#         data_root='data/Triangle_215_Keypoint_coco/',
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(1333, 800), keep_ratio=True),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# val_evaluator = [
#     dict(
#         type='CocoMetric',
#         ann_file='data/Triangle_215_Keypoint_coco/val_coco.json',
#         metric='bbox',
#         format_only=False,
#         backend_args=None),
#     dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# ]
# test_evaluator = [
#     dict(
#         type='CocoMetric',
#         ann_file='data/Triangle_215_Keypoint_coco/val_coco.json',
#         metric='bbox',
#         format_only=False,
#         backend_args=None),
#     dict(type='VOCMetric', metric='mAP', eval_mode='11points')
# ]
# model = dict(
#     type='FasterRCNN',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[123.675, 116.28, 103.53],
#         std=[58.395, 57.12, 57.375],
#         bgr_to_rgb=True,
#         pad_size_divisor=32),
#     backbone=dict(
#         type='ResNet',
#         depth=50,
#         num_stages=4,
#         out_indices=(0, 1, 2, 3),
#         frozen_stages=1,
#         norm_cfg=dict(type='BN', requires_grad=True),
#         norm_eval=True,
#         style='pytorch',
#         init_cfg=dict(type='Pretrained', checkpoint='torchvision://resnet50')),
#     neck=dict(
#         type='FPN',
#         in_channels=[256, 512, 1024, 2048],
#         out_channels=256,
#         num_outs=5),
#     rpn_head=dict(
#         type='RPNHead',
#         in_channels=256,
#         feat_channels=256,
#         anchor_generator=dict(
#             type='AnchorGenerator',
#             scales=[8],
#             ratios=[0.5, 1.0, 2.0],
#             strides=[4, 8, 16, 32, 64]),
#         bbox_coder=dict(
#             type='DeltaXYWHBBoxCoder',
#             target_means=[0.0, 0.0, 0.0, 0.0],
#             target_stds=[1.0, 1.0, 1.0, 1.0]),
#         loss_cls=dict(
#             type='CrossEntropyLoss', use_sigmoid=True, loss_weight=1.0),
#         loss_bbox=dict(type='L1Loss', loss_weight=1.0)),
#     roi_head=dict(
#         type='StandardRoIHead',
#         bbox_roi_extractor=dict(
#             type='SingleRoIExtractor',
#             roi_layer=dict(type='RoIAlign', output_size=7, sampling_ratio=0),
#             out_channels=256,
#             featmap_strides=[4, 8, 16, 32]),
#         bbox_head=dict(
#             type='Shared2FCBBoxHead',
#             in_channels=256,
#             fc_out_channels=1024,
#             roi_feat_size=7,
#             num_classes=1,
#             bbox_coder=dict(
#                 type='DeltaXYWHBBoxCoder',
#                 target_means=[0.0, 0.0, 0.0, 0.0],
#                 target_stds=[0.1, 0.1, 0.2, 0.2]),
#             reg_class_agnostic=False,
#             loss_cls=dict(
#                 type='CrossEntropyLoss', use_sigmoid=False, loss_weight=1.0),
#             loss_bbox=dict(type='L1Loss', loss_weight=1.0))),
#     train_cfg=dict(
#         rpn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.7,
#                 neg_iou_thr=0.3,
#                 min_pos_iou=0.3,
#                 match_low_quality=True,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=256,
#                 pos_fraction=0.5,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=False),
#             allowed_border=-1,
#             pos_weight=-1,
#             debug=False),
#         rpn_proposal=dict(
#             nms_pre=2000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             assigner=dict(
#                 type='MaxIoUAssigner',
#                 pos_iou_thr=0.5,
#                 neg_iou_thr=0.5,
#                 min_pos_iou=0.5,
#                 match_low_quality=False,
#                 ignore_iof_thr=-1),
#             sampler=dict(
#                 type='RandomSampler',
#                 num=512,
#                 pos_fraction=0.25,
#                 neg_pos_ub=-1,
#                 add_gt_as_proposals=True),
#             pos_weight=-1,
#             debug=False)),
#     test_cfg=dict(
#         rpn=dict(
#             nms_pre=1000,
#             max_per_img=1000,
#             nms=dict(type='nms', iou_threshold=0.7),
#             min_bbox_size=0),
#         rcnn=dict(
#             score_thr=0.05,
#             nms=dict(type='nms', iou_threshold=0.5),
#             max_per_img=100)))
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=0.001, by_epoch=False, begin=0, end=500),
#     dict(
#         type='MultiStepLR',
#         begin=0,
#         end=12,
#         by_epoch=True,
#         milestones=[8, 11],
#         gamma=0.1)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='SGD', lr=0.02, momentum=0.9, weight_decay=0.0001))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=1,
#         max_keep_ckpts=2,
#         save_best='coco/bbox_mAP'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# resume = False
# launcher = 'none'
# work_dir = './work_dirs/faster_r_cnn_triangle'
# 06/03 20:39:06 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/03 20:39:06 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/03 20:39:07 - mmengine - INFO - load model from: torchvision://resnet50
# 06/03 20:39:07 - mmengine - INFO - Loads checkpoint by torchvision backend from path: torchvision://resnet50
# 06/03 20:39:07 - mmengine - WARNING - The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: fc.weight, fc.bias
#
# 06/03 20:39:07 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 06/03 20:39:07 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 06/03 20:39:07 - mmengine - INFO - Checkpoints will be saved to /media/zhou/B6E23E81E23E4641/OpenMMLab2Learn-main/mmdetection/work_dirs/faster_r_cnn_triangle.
# 06/03 20:39:08 - mmengine - INFO - Epoch(train)  [1][ 1/86]  lr: 2.0000e-05  eta: 1:20:33  time: 1.1242  data_time: 0.3111  memory: 3047  loss: 1.6695  loss_rpn_cls: 0.7183  loss_rpn_bbox: 0.0409  loss_cls: 0.8996  acc: 7.9102  loss_bbox: 0.0107
# 06/03 20:39:08 - mmengine - INFO - Epoch(train)  [1][ 2/86]  lr: 6.0040e-05  eta: 0:50:52  time: 0.7102  data_time: 0.1577  memory: 3314  loss: 1.5956  loss_rpn_cls: 0.7194  loss_rpn_bbox: 0.0243  loss_cls: 0.8465  acc: 31.5430  loss_bbox: 0.0055
# 06/03 20:39:08 - mmengine - INFO - Epoch(train)  [1][ 3/86]  lr: 1.0008e-04  eta: 0:40:59  time: 0.5724  data_time: 0.1064  memory: 3502  loss: 1.5377  loss_rpn_cls: 0.7189  loss_rpn_bbox: 0.0216  loss_cls: 0.7928  acc: 56.5430  loss_bbox: 0.0044
# 06/03 20:39:09 - mmengine - INFO - Epoch(train)  [1][ 4/86]  lr: 1.4012e-04  eta: 0:35:58  time: 0.5025  data_time: 0.0806  memory: 3314  loss: 1.4753  loss_rpn_cls: 0.7200  loss_rpn_bbox: 0.0224  loss_cls: 0.7216  acc: 95.1172  loss_bbox: 0.0113
# 06/03 20:39:09 - mmengine - INFO - Epoch(train)  [1][ 5/86]  lr: 1.8016e-04  eta: 0:32:21  time: 0.4522  data_time: 0.0652  memory: 3179  loss: 1.3982  loss_rpn_cls: 0.7195  loss_rpn_bbox: 0.0195  loss_cls: 0.6455  acc: 98.8281  loss_bbox: 0.0137
# 06/03 20:39:09 - mmengine - INFO - Epoch(train)  [1][ 6/86]  lr: 2.2020e-04  eta: 0:30:26  time: 0.4253  data_time: 0.0549  memory: 3314  loss: 1.3220  loss_rpn_cls: 0.7186  loss_rpn_bbox: 0.0176  loss_cls: 0.5722  acc: 99.2188  loss_bbox: 0.0136
# 06/03 20:39:10 - mmengine - INFO - Epoch(train)  [1][ 7/86]  lr: 2.6024e-04  eta: 0:29:02  time: 0.4058  data_time: 0.0476  memory: 3502  loss: 1.2543  loss_rpn_cls: 0.7183  loss_rpn_bbox: 0.0183  loss_cls: 0.5041  acc: 99.3164  loss_bbox: 0.0137
# 06/03 20:39:10 - mmengine - INFO - Epoch(train)  [1][ 8/86]  lr: 3.0028e-04  eta: 0:28:08  time: 0.3935  data_time: 0.0421  memory: 3314  loss: 1.2017  loss_rpn_cls: 0.7179  loss_rpn_bbox: 0.0201  loss_cls: 0.4489  acc: 99.0234  loss_bbox: 0.0148
# 06/03 20:39:10 - mmengine - INFO - Epoch(train)  [1][ 9/86]  lr: 3.4032e-04  eta: 0:27:07  time: 0.3793  data_time: 0.0378  memory: 3179  loss: 1.1553  loss_rpn_cls: 0.7174  loss_rpn_bbox: 0.0192  loss_cls: 0.4040  acc: 99.3164  loss_bbox: 0.0147
# 06/03 20:39:10 - mmengine - INFO - Epoch(train)  [1][10/86]  lr: 3.8036e-04  eta: 0:26:13  time: 0.3669  data_time: 0.0345  memory: 3179  loss: 1.1150  loss_rpn_cls: 0.7166  loss_rpn_bbox: 0.0181  loss_cls: 0.3659  acc: 99.4141  loss_bbox: 0.0145
# 06/03 20:39:11 - mmengine - INFO - Epoch(train)  [1][11/86]  lr: 4.2040e-04  eta: 0:25:45  time: 0.3603  data_time: 0.0317  memory: 3314  loss: 1.0809  loss_rpn_cls: 0.7154  loss_rpn_bbox: 0.0173  loss_cls: 0.3343  acc: 99.5117  loss_bbox: 0.0138
# 06/03 20:39:11 - mmengine - INFO - Epoch(train)  [1][12/86]  lr: 4.6044e-04  eta: 0:25:24  time: 0.3555  data_time: 0.0294  memory: 3314  loss: 1.0558  loss_rpn_cls: 0.7143  loss_rpn_bbox: 0.0173  loss_cls: 0.3092  acc: 99.0234  loss_bbox: 0.0150
# 06/03 20:41:33 - mmengine - INFO - Epoch(train)  [5][85/86]  lr: 1.7157e-02  eta: 0:20:51  time: 0.3126  data_time: 0.0039  memory: 3178  loss: 0.2207  loss_rpn_cls: 0.0078  loss_rpn_bbox: 0.0179  loss_cls: 0.0712  acc: 97.8516  loss_bbox: 0.1238
# Traceback (most recent call last):
#   File "tools/train.py", line 133, in <module>
#     main()
#   File "tools/train.py", line 129, in main
#     runner.train()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/runner.py", line 1721, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/loops.py", line 112, in run_epoch
#     self.run_iter(idx, data_batch)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/loops.py", line 129, in run_iter
#     data_batch, optim_wrapper=self.runner.optim_wrapper)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/model/base_model/base_model.py", line 116, in train_step
#     optim_wrapper.update_params(parsed_losses)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/optim/optimizer/optimizer_wrapper.py", line 184, in update_params
#     self.backward(loss)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/optim/optimizer/optimizer_wrapper.py", line 208, in backward
#     loss.backward(**kwargs)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/autograd/__init__.py", line 147, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/autograd/function.py", line 89, in apply
#     return self._forward_cls.backward(self, *args)  # type: ignore
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/autograd/function.py", line 210, in wrapper
#     outputs = fn(ctx, *args)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmcv/ops/roi_align.py", line 110, in backward
#     grad_input = grad_output.new_zeros(ctx.input_shape)
# RuntimeError: CUDA out of memory. Tried to allocate 200.00 MiB (GPU 0; 7.77 GiB total capacity; 4.54 GiB already allocated; 192.06 MiB free; 4.92 GiB reserved in total by PyTorch)

# %% [markdown]
# ## 目标检测算法：RTMDet

# %%
# 建议在命令行中运行
# !python tools/train.py data/rtmdet_tiny_triangle.py
# Out:
# 06/04 11:49:09 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.7.9 (default, Aug 31 2020, 12:42:55) [GCC 7.3.0]
#     CUDA available: True
#     numpy_random_seed: 1385187271
#     GPU 0: Graphics Device
#     CUDA_HOME: /usr/local/cuda-11.1
#     NVCC: Cuda compilation tools, release 11.1, V11.1.105
#     GCC: gcc (Ubuntu 7.5.0-3ubuntu1~18.04) 7.5.0
#     PyTorch: 1.8.0+cu111
#     PyTorch compiling details: PyTorch built with:
#   - GCC 7.3
#   - C++ Version: 201402
#   - Intel(R) Math Kernel Library Version 2020.0.0 Product Build 20191122 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v1.7.0 (Git Hash 7aed236906b1f7a05c0917e5257a1af05e9ff683)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - CUDA Runtime 11.1
#   - NVCC architecture flags: -gencode;arch=compute_37,code=sm_37;-gencode;arch=compute_50,code=sm_50;-gencode;arch=compute_60,code=sm_60;-gencode;arch=compute_70,code=sm_70;-gencode;arch=compute_75,code=sm_75;-gencode;arch=compute_80,code=sm_80;-gencode;arch=compute_86,code=sm_86
#   - CuDNN 8.0.5
#   - Magma 2.5.2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=11.1, CUDNN_VERSION=8.0.5, CXX_COMPILER=/opt/rh/devtoolset-7/root/usr/bin/c++, CXX_FLAGS= -Wno-deprecated -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -fopenmp -DNDEBUG -DUSE_KINETO -DUSE_FBGEMM -DUSE_QNNPACK -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -O2 -fPIC -Wno-narrowing -Wall -Wextra -Werror=return-type -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-sign-compare -Wno-unused-parameter -Wno-unused-variable -Wno-unused-function -Wno-unused-result -Wno-unused-local-typedefs -Wno-strict-overflow -Wno-strict-aliasing -Wno-error=deprecated-declarations -Wno-stringop-overflow -Wno-psabi -Wno-error=pedantic -Wno-error=redundant-decls -Wno-error=old-style-cast -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, PERF_WITH_AVX512=1, TORCH_VERSION=1.8.0, USE_CUDA=ON, USE_CUDNN=ON, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=ON, USE_NNPACK=ON, USE_OPENMP=ON,
#
#     TorchVision: 0.9.0+cu111
#     OpenCV: 4.5.1
#     MMEngine: 0.7.3
#
# Runtime environment:
#     cudnn_benchmark: False
#     mp_cfg: {'mp_start_method': 'fork', 'opencv_num_threads': 0}
#     dist_cfg: {'backend': 'nccl'}
#     seed: None
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 06/04 11:49:09 - mmengine - INFO - Config:
# dataset_type = 'CocoDataset'
# data_root = 'data/Triangle_215_Keypoint_coco/'
# metainfo = dict(classes=('sjb_rect', ))
# NUM_CLASSES = 1
# load_from = None
# backbone_pretrain = 'https://download.openmmlab.com/mmdetection/v3.0/rtmdet/cspnext_rsb_pretrain/cspnext-tiny_imagenet_600e.pth'
# deepen_factor = 0.167
# widen_factor = 0.375
# in_channels = [96, 192, 384]
# neck_out_channels = 96
# num_csp_blocks = 1
# exp_on_reg = False
# MAX_EPOCHS = 200
# TRAIN_BATCH_SIZE = 4
# VAL_BATCH_SIZE = 2
# stage2_num_epochs = 20
# base_lr = 0.004
# VAL_INTERVAL = 5
# default_scope = 'mmdet'
# default_hooks = dict(
#     timer=dict(type='IterTimerHook'),
#     logger=dict(type='LoggerHook', interval=1),
#     param_scheduler=dict(type='ParamSchedulerHook'),
#     checkpoint=dict(
#         type='CheckpointHook',
#         interval=10,
#         max_keep_ckpts=2,
#         save_best='coco/bbox_mAP'),
#     sampler_seed=dict(type='DistSamplerSeedHook'),
#     visualization=dict(type='DetVisualizationHook'))
# env_cfg = dict(
#     cudnn_benchmark=False,
#     mp_cfg=dict(mp_start_method='fork', opencv_num_threads=0),
#     dist_cfg=dict(backend='nccl'))
# vis_backends = [dict(type='LocalVisBackend')]
# visualizer = dict(
#     type='DetLocalVisualizer',
#     vis_backends=[dict(type='LocalVisBackend')],
#     name='visualizer')
# log_processor = dict(type='LogProcessor', window_size=50, by_epoch=True)
# log_level = 'INFO'
# resume = False
# train_cfg = dict(
#     type='EpochBasedTrainLoop',
#     max_epochs=200,
#     val_interval=5,
#     dynamic_intervals=[(180, 1)])
# val_cfg = dict(type='ValLoop')
# test_cfg = dict(type='TestLoop')
# param_scheduler = [
#     dict(
#         type='LinearLR', start_factor=1e-05, by_epoch=False, begin=0,
#         end=1000),
#     dict(
#         type='CosineAnnealingLR',
#         eta_min=0.0002,
#         begin=150,
#         end=300,
#         T_max=150,
#         by_epoch=True,
#         convert_to_iter_based=True)
# ]
# optim_wrapper = dict(
#     type='OptimWrapper',
#     optimizer=dict(type='AdamW', lr=0.004, weight_decay=0.05),
#     paramwise_cfg=dict(
#         norm_decay_mult=0, bias_decay_mult=0, bypass_duplicate=True))
# auto_scale_lr = dict(enable=False, base_batch_size=16)
# backend_args = None
# train_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='CachedMosaic',
#         img_scale=(640, 640),
#         pad_val=114.0,
#         max_cached_images=20,
#         random_pop=False),
#     dict(
#         type='RandomResize',
#         scale=(1280, 1280),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='CachedMixUp',
#         img_scale=(640, 640),
#         ratio_range=(1.0, 1.0),
#         max_cached_images=10,
#         random_pop=False,
#         pad_val=(114, 114, 114),
#         prob=0.5),
#     dict(type='PackDetInputs')
# ]
# test_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='Resize', scale=(640, 640), keep_ratio=True),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(
#         type='PackDetInputs',
#         meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                    'scale_factor'))
# ]
# train_dataloader = dict(
#     batch_size=4,
#     num_workers=4,
#     persistent_workers=True,
#     sampler=dict(type='DefaultSampler', shuffle=True),
#     batch_sampler=None,
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_215_Keypoint_coco/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='train_coco.json',
#         data_prefix=dict(img='images/'),
#         filter_cfg=dict(filter_empty_gt=True, min_size=32),
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='CachedMosaic',
#                 img_scale=(640, 640),
#                 pad_val=114.0,
#                 max_cached_images=20,
#                 random_pop=False),
#             dict(
#                 type='RandomResize',
#                 scale=(1280, 1280),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='CachedMixUp',
#                 img_scale=(640, 640),
#                 ratio_range=(1.0, 1.0),
#                 max_cached_images=10,
#                 random_pop=False,
#                 pad_val=(114, 114, 114),
#                 prob=0.5),
#             dict(type='PackDetInputs')
#         ],
#         backend_args=None),
#     pin_memory=True)
# val_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_215_Keypoint_coco/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# test_dataloader = dict(
#     batch_size=2,
#     num_workers=2,
#     persistent_workers=True,
#     drop_last=False,
#     sampler=dict(type='DefaultSampler', shuffle=False),
#     dataset=dict(
#         type='CocoDataset',
#         data_root='data/Triangle_215_Keypoint_coco/',
#         metainfo=dict(classes=('sjb_rect', )),
#         ann_file='val_coco.json',
#         data_prefix=dict(img='images/'),
#         test_mode=True,
#         pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='Resize', scale=(640, 640), keep_ratio=True),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(
#                 type='PackDetInputs',
#                 meta_keys=('img_id', 'img_path', 'ori_shape', 'img_shape',
#                            'scale_factor'))
#         ],
#         backend_args=None))
# val_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data/Triangle_215_Keypoint_coco/val_coco.json',
#     metric=['bbox'],
#     format_only=False,
#     backend_args=None,
#     proposal_nums=(100, 1, 10))
# test_evaluator = dict(
#     type='CocoMetric',
#     ann_file='data/Triangle_215_Keypoint_coco/val_coco.json',
#     metric=['bbox'],
#     format_only=False,
#     backend_args=None,
#     proposal_nums=(100, 1, 10))
# tta_model = dict(
#     type='DetTTAModel',
#     tta_cfg=dict(nms=dict(type='nms', iou_threshold=0.6), max_per_img=100))
# tta_pipeline = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(
#         type='TestTimeAug',
#         transforms=[[{
#             'type': 'Resize',
#             'scale': (640, 640),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (320, 320),
#             'keep_ratio': True
#         }, {
#             'type': 'Resize',
#             'scale': (960, 960),
#             'keep_ratio': True
#         }],
#                     [{
#                         'type': 'RandomFlip',
#                         'prob': 1.0
#                     }, {
#                         'type': 'RandomFlip',
#                         'prob': 0.0
#                     }],
#                     [{
#                         'type': 'Pad',
#                         'size': (960, 960),
#                         'pad_val': {
#                             'img': (114, 114, 114)
#                         }
#                     }],
#                     [{
#                         'type':
#                         'PackDetInputs',
#                         'meta_keys':
#                         ('img_id', 'img_path', 'ori_shape', 'img_shape',
#                          'scale_factor', 'flip', 'flip_direction')
#                     }]])
# ]
# model = dict(
#     type='RTMDet',
#     data_preprocessor=dict(
#         type='DetDataPreprocessor',
#         mean=[103.53, 116.28, 123.675],
#         std=[57.375, 57.12, 58.395],
#         bgr_to_rgb=False,
#         batch_augments=None),
#     backbone=dict(
#         type='CSPNeXt',
#         arch='P5',
#         expand_ratio=0.5,
#         deepen_factor=0.167,
#         widen_factor=0.375,
#         channel_attention=True,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True),
#         init_cfg=dict(
#             type='Pretrained',
#             prefix='backbone.',
#             checkpoint=
#             'https://download.openmmlab.com/mmdetection/v3.0/rtmdet/cspnext_rsb_pretrain/cspnext-tiny_imagenet_600e.pth'
#         )),
#     neck=dict(
#         type='CSPNeXtPAFPN',
#         in_channels=[96, 192, 384],
#         out_channels=96,
#         num_csp_blocks=1,
#         expand_ratio=0.5,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     bbox_head=dict(
#         type='RTMDetSepBNHead',
#         num_classes=1,
#         in_channels=96,
#         stacked_convs=2,
#         feat_channels=96,
#         anchor_generator=dict(
#             type='MlvlPointGenerator', offset=0, strides=[8, 16, 32]),
#         bbox_coder=dict(type='DistancePointBBoxCoder'),
#         loss_cls=dict(
#             type='QualityFocalLoss',
#             use_sigmoid=True,
#             beta=2.0,
#             loss_weight=1.0),
#         loss_bbox=dict(type='GIoULoss', loss_weight=2.0),
#         with_objectness=False,
#         exp_on_reg=False,
#         share_conv=True,
#         pred_kernel_size=1,
#         norm_cfg=dict(type='SyncBN'),
#         act_cfg=dict(type='SiLU', inplace=True)),
#     train_cfg=dict(
#         assigner=dict(type='DynamicSoftLabelAssigner', topk=13),
#         allowed_border=-1,
#         pos_weight=-1,
#         debug=False),
#     test_cfg=dict(
#         nms_pre=30000,
#         min_bbox_size=0,
#         score_thr=0.001,
#         nms=dict(type='nms', iou_threshold=0.65),
#         max_per_img=300))
# train_pipeline_stage2 = [
#     dict(type='LoadImageFromFile', backend_args=None),
#     dict(type='LoadAnnotations', with_bbox=True),
#     dict(
#         type='RandomResize',
#         scale=(640, 640),
#         ratio_range=(0.5, 2.0),
#         keep_ratio=True),
#     dict(type='RandomCrop', crop_size=(640, 640)),
#     dict(type='YOLOXHSVRandomAug'),
#     dict(type='RandomFlip', prob=0.5),
#     dict(type='Pad', size=(640, 640), pad_val=dict(img=(114, 114, 114))),
#     dict(type='PackDetInputs')
# ]
# custom_hooks = [
#     dict(
#         type='EMAHook',
#         ema_type='ExpMomentumEMA',
#         momentum=0.0002,
#         update_buffers=True,
#         priority=49),
#     dict(
#         type='PipelineSwitchHook',
#         switch_epoch=180,
#         switch_pipeline=[
#             dict(type='LoadImageFromFile', backend_args=None),
#             dict(type='LoadAnnotations', with_bbox=True),
#             dict(
#                 type='RandomResize',
#                 scale=(640, 640),
#                 ratio_range=(0.5, 2.0),
#                 keep_ratio=True),
#             dict(type='RandomCrop', crop_size=(640, 640)),
#             dict(type='YOLOXHSVRandomAug'),
#             dict(type='RandomFlip', prob=0.5),
#             dict(
#                 type='Pad', size=(640, 640),
#                 pad_val=dict(img=(114, 114, 114))),
#             dict(type='PackDetInputs')
#         ])
# ]
# launcher = 'none'
# work_dir = './work_dirs/rtmdet_tiny_triangle'
# 06/04 11:49:17 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 06/04 11:49:17 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_load_checkpoint:
# (49          ) EMAHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
# (NORMAL      ) PipelineSwitchHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_save_checkpoint:
# (49          ) EMAHook
#  --------------------
# after_train:
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test_epoch:
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DetVisualizationHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (49          ) EMAHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# loading annotations into memory...
# Done (t=0.15s)
# creating index...
# index created!
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stem.2.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage1.1.attention.fc.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage2.1.attention.fc.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage3.1.attention.fc.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.1.conv2.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- backbone.stage4.2.attention.fc.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.reduce_layers.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.reduce_layers.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.downsamples.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.downsamples.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.main_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.short_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.final_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- neck.out_convs.2.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.0.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.cls_convs.1.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.cls_convs.1.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.1.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.cls_convs.2.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.cls_convs.2.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.cls_convs.2.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.0.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.reg_convs.1.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.reg_convs.1.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.1.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.reg_convs.2.0.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.0.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.0.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - WARNING - bbox_head.reg_convs.2.1.conv is duplicate. It is skipped since bypass_duplicate=True
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.1.bn.weight:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.reg_convs.2.1.bn.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.0.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.1.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_cls.2.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.0.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.1.bias:weight_decay=0.0
# 06/04 11:49:18 - mmengine - INFO - paramwise_options -- bbox_head.rtm_reg.2.bias:weight_decay=0.0
# loading annotations into memory...
# Done (t=0.16s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# 06/04 11:49:31 - mmengine - INFO - Epoch(train)   [1][11/43]  lr: 4.0080e-05  eta: 1:37:34  time: 0.6817  data_time: 0.4746  memory: 1341  loss: 0.0628  loss_cls: 0.0351  loss_bbox: 0.0277
# 06/04 11:49:31 - mmengine - INFO - Epoch(train)   [1][12/43]  lr: 4.4084e-05  eta: 1:30:55  time: 0.6353  data_time: 0.4353  memory: 1338  loss: 0.0676  loss_cls: 0.0351  loss_bbox: 0.0325
# 06/04 11:49:32 - mmengine - INFO - Epoch(train)   [1][13/43]  lr: 4.8088e-05  eta: 1:41:44  time: 0.7109  data_time: 0.5172  memory: 1342  loss: 0.0840  loss_cls: 0.0350  loss_bbox: 0.0490
# 06/04 11:49:33 - mmengine - INFO - Epoch(train)   [1][14/43]  lr: 5.2092e-05  eta: 1:39:47  time: 0.6974  data_time: 0.5087  memory: 1343  loss: 0.0920  loss_cls: 0.0350  loss_bbox: 0.0570
# 06/04 11:49:33 - mmengine - INFO - Epoch(train)   [1][15/43]  lr: 5.6095e-05  eta: 1:34:29  time: 0.6603  data_time: 0.4751  memory: 1340  loss: 0.0959  loss_cls: 0.0349  loss_bbox: 0.0610
# 06/04 11:49:33 - mmengine - INFO - Epoch(train)   [1][16/43]  lr: 6.0099e-05  eta: 1:29:48  time: 0.6278  data_time: 0.4456  memory: 1340  loss: 0.1039  loss_cls: 0.0349  loss_bbox: 0.0691
# ^C
# Traceback (most recent call last):
#   File "tools/train.py", line 133, in <module>
#     main()
#   File "tools/train.py", line 129, in main
#     runner.train()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/runner.py", line 1721, in train
#     model = self.train_loop.run()  # type: ignore
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/loops.py", line 96, in run
#     self.run_epoch()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/mmengine/runner/loops.py", line 111, in run_epoch
#     for idx, data_batch in enumerate(self.dataloader):
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 517, in __next__
#     data = self._next_data()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1182, in _next_data
#     idx, data = self._get_data()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 1138, in _get_data
#     success, data = self._try_get_data()
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/site-packages/torch/utils/data/dataloader.py", line 986, in _try_get_data
#     data = self._data_queue.get(timeout=timeout)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/queue.py", line 179, in get
#     self.not_empty.wait(remaining)
#   File "/home/zhou/anaconda3/envs/torch_gpu/lib/python3.7/threading.py", line 300, in wait
#     gotit = waiter.acquire(True, timeout)
# KeyboardInterrupt

# %% [markdown]
# ## 在`work_dirs`目录下，查看训练日志和训练得到的模型权重文件

# %% [markdown]
# ## 测试集上评估模型精度

# %%
# !python tools/test.py data/rtmdet_tiny_triangle.py \
                      work_dirs/rtmdet_tiny_triangle/epoch_200.pth
